# %% [markdown]
# # Day 4

# %%
from typing import List
import re

# %%
# Input data
# References: 
# - https://stackoverflow.com/questions/4998629/split-string-with-multiple-delimiters-in-python
# - https://stackoverflow.com/questions/3371269/call-int-function-on-every-list-element
with open("04_input.txt") as f:
    my_list = f.read().splitlines()
    my_list = [list(map(int, re.split("-|,", item))) for item in my_list]

my_list
# Out:
# [[57, 93, 9, 57],
#  [55, 55, 55, 83],
#  [55, 88, 78, 88],
#  [24, 24, 24, 95],
#  [7, 92, 8, 93],
#  [25, 84, 84, 85],
#  [62, 85, 62, 85],
#  [66, 78, 65, 76],
#  [28, 32, 31, 33],
#  [24, 81, 2, 25],
#  [45, 80, 79, 80],
#  [75, 99, 75, 91],
#  [24, 49, 23, 24],
#  [22, 69, 49, 69],
#  [15, 77, 76, 78],
#  [25, 50, 21, 50],
#  [29, 77, 29, 64],
#  [47, 93, 46, 48],
#  [37, 42, 70, 97],
#  [5, 95, 4, 6],
#  [37, 90, 74, 95],
#  [17, 48, 18, 85],
#  [2, 97, 1, 89],
#  [2, 48, 1, 48],
#  [52, 70, 42, 71],
#  [17, 90, 90, 94],
#  [76, 77, 2, 76],
#  [10, 89, 10, 96],
#  [40, 52, 39, 53],
#  [9, 97, 8, 96],
#  [6, 74, 5, 6],
#  [3, 89, 2, 89],
#  [35, 63, 62, 79],
#  [13, 39, 18, 39],
#  [45, 81, 4, 46],
#  [8, 76, 39, 67],
#  [3, 76, 1, 4],
#  [1, 96, 1, 1],
#  [11, 59, 58, 60],
#  [41, 53, 25, 42],
#  [5, 54, 11, 93],
#  [15, 91, 95, 95],
#  [62, 62, 2, 63],
#  [11, 41, 40, 42],
#  [52, 98, 51, 53],
#  [29, 52, 47, 51],
#  [15, 86, 16, 86],
#  [13, 98, 28, 99],
#  [8, 13, 14, 54],
# ...

# %% [markdown]
# # Part 1

# %%
def solution(assignment_pairs: List) -> int:
    # Initialize useful variables
    number_of_pairs_with_full_overlap = 0

    # Loop through all assignment pairs and count the number of 
    # cases where one assignment is fully contained in the other
    for pair in assignment_pairs:
        start_a, end_a, start_b, end_b = pair
        a_in_b = (start_a >= start_b) and (end_a <= end_b) 
        b_in_a = (start_b >= start_a) and (end_b <= end_a) 
        if a_in_b or b_in_a:
            number_of_pairs_with_full_overlap += 1
    
    return number_of_pairs_with_full_overlap

# %%
solution(my_list) # correct: 471
# Out:
# 471

# %% [markdown]
# **Test cases**

# %%
assignment_pairs = [
    [2, 4, 6, 8], 
    [2, 3, 4, 5], 
    [5, 7, 7, 9], 
    [2, 8, 3, 7], 
    [6, 6, 4, 6], 
    [2, 6, 4, 8]
]
expected = 2
assert solution(assignment_pairs) == expected

# %%
rucksack_contents = [
    [2, 4, 6, 8]
]
expected = 0 
assert solution(rucksack_contents) == expected

# %%
rucksack_contents = [
    [1, 1, 1, 1]
]
expected = 1
assert solution(rucksack_contents) == expected

# %% [markdown]
# # Part 2

# %%
def solution(assignment_pairs: List) -> int:
    # Initialize useful variables
    number_of_pairs_with_partial_overlap = 0

    # Loop through all assignment pairs and count the number of 
    # cases where one assignment is fully contained in the other
    for pair in assignment_pairs:
        start_a, end_a, start_b, end_b = pair
        a_before_b = (end_a < start_b) 
        b_before_a = (end_b < start_a) 
        if (not a_before_b) and (not b_before_a):
            number_of_pairs_with_partial_overlap += 1
    
    return number_of_pairs_with_partial_overlap

# %%
solution(my_list) # correct: 888
# Out:
# 888

# %% [markdown]
# **Test cases**

# %%
assignment_pairs = [
    [2, 4, 6, 8], 
    [2, 3, 4, 5], 
    [5, 7, 7, 9], 
    [2, 8, 3, 7], 
    [6, 6, 4, 6], 
    [2, 6, 4, 8]
]
expected = 4
assert solution(assignment_pairs) == expected

# %%
rucksack_contents = [
    [2, 4, 6, 8]
]
expected = 0 
assert solution(rucksack_contents) == expected

# %%
rucksack_contents = [
    [1, 3, 2, 5]
]
expected = 1
assert solution(rucksack_contents) == expected
